# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# ### Carga de datos

# %%
# datos de BIARE de 2021
df_cb_21 = "Dataset/biare_cb_1021.csv"
# datos de BIARE de 2022
df_cb_22 = "Dataset/biare_cb_1022.csv"
# datos de BIARE de 2023
df_cb_23 = "Dataset/biare_cb_1023.csv"
# datos de BIARE de 2024
df_cb_24 = "Dataset/biare_cb_1124.csv"

# %%
# datos sociodemograficos de 2021
df_cs_21 = "Dataset/biare_cs_1021.csv"
# datos sociodemograficos de 2022
df_cs_22 = "Dataset/biare_cs_1022.csv"
# datos sociodemograficos de 2023
df_cs_23 = "Dataset/biare_cs_1023.csv"
# datos sociodemograficos de 2024
df_cs_24 = "Dataset/biare_cs_1124.csv"

# %%
# datos de vivienda de 2021
df_viv_21 = "Dataset/biare_viv_1021.csv"
# datos de vivienda de 2022
df_viv_22 = "Dataset/biare_viv_1022.csv"
# datos de vivienda de 2023
df_viv_23 = "Dataset/biare_viv_1023.csv"
# datos de vivienda de 2024
df_viv_24 = "Dataset/biare_viv_1124.csv"
