# %% [markdown]
# # Limpieza de datos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carga de datos

# %%
# datos de BIARE de 2021
df_cb_21 = pd.read_csv("../Dataset/biare_cb_1021.csv")
# datos de BIARE de 2022
df_cb_22 = pd.read_csv("../Dataset/biare_cb_1022.csv")
# datos de BIARE de 2023
df_cb_23 = pd.read_csv("../Dataset/biare_cb_1023.csv")
# datos de BIARE de 2024
df_cb_24 = pd.read_csv("../Dataset/biare_cb_1124.csv")

# %%
# datos sociodemograficos de 2021
df_cs_21 = pd.read_csv("../Dataset/biare_cs_1021.csv")
# datos sociodemograficos de 2022
df_cs_22 = pd.read_csv("../Dataset/biare_cs_1022.csv")
# datos sociodemograficos de 2023
df_cs_23 = pd.read_csv("../Dataset/biare_cs_1023.csv")
# datos sociodemograficos de 2024
df_cs_24 = pd.read_csv("../Dataset/biare_cs_1124.csv")

# %%
# datos de vivienda de 2021
df_viv_21 = pd.read_csv("../Dataset/biare_viv_1021.csv")
# datos de vivienda de 2022
df_viv_22 = pd.read_csv("../Dataset/biare_viv_1022.csv")
# datos de vivienda de 2023
df_viv_23 = pd.read_csv("../Dataset/biare_viv_1023.csv")
# datos de vivienda de 2024
df_viv_24 = pd.read_csv("../Dataset/biare_viv_1124.csv")

# %% [markdown]
# ### Analizamos el contenido de las tablas para encontrar anomalias

# %%
df_cb_21.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PER      1969 non-null   int64
#  1   N_ENT    1969 non-null   int64
#  2   FOL      1969 non-null   str
#  3   ENT      1969 non-null   int64
#  4   CON      1969 non-null   int64
#  5   V_SEL    1969 non-null   int64
#  6   N_HOG    1969 non-null   int64
#  7   H_MUD    1969 non-null   int64
#  8   N_REN    1969 non-null   int64
#  9   P1       1969 non-null   int64
#  10  P2       1969 non-null   int64
#  11  P3_1     1969 non-null   int64
#  12  P3_2     1969 non-null   int64
#  13  P3_3     1969 non-null   int64
#  14  P3_4     1969 non-null   int64
#  15  P3_5     1969 non-null   int64
#  16  P3_6     1969 non-null   int64
#  17  P3_7     1969 non-null   int64
#  18  P3_8     1969 non-null   int64
#  19  P3_9     1969 non-null   int64
#  20  P3_10    1969 non-null   int64
#  21  P3_11    1969 non-null   int64
#  22  P4_1     1969 non-null   int64
#  23  P4_2     1969 non-null   int64
#  24  P4_3     1969 non-null   int64
#  25  P4_4     1969 non-null   int64
#  26  P4_5     1969 non-null   int64
#  27  P4_6     1969 non-null   int64
#  28  P4_7     1969 non-null   int64
#  29  P4_8     1969 non-null   int64
#  30  P4_9     1969 non-null   int64
#  31  P4_10    1969 non-null   int64
#  32  P5_1     1969 non-null   int64
#  33  P5_2     1969 non-null   int64
#  34  P5_3     1969 non-null   int64
#  35  P5_4     1969 non-null   int64
#  36  P5_5     1969 non-null   int64
#  37  P5_6     1969 non-null   int64
#  38  P5_7     1969 non-null   int64
#  39  P5_8     1969 non-null   int64
#  40  P5_9     1969 non-null   int64
#  41  P5_10    1969 non-null   int64
#  42  P5_11    1969 non-null   int64
#  43  P5_12    1969 non-null   int64
#  44  TIPO     1969 non-null   int64
#  45  FAC_MOD  1969 non-null   int64
# dtypes: int64(45), str(1)
# memory usage: 707.7 KB

# %%
df_cb_22.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PER      2013 non-null   int64
#  1   N_ENT    2013 non-null   int64
#  2   FOL      2013 non-null   str
#  3   ENT      2013 non-null   int64
#  4   CON      2013 non-null   int64
#  5   V_SEL    2013 non-null   int64
#  6   N_HOG    2013 non-null   int64
#  7   H_MUD    2013 non-null   int64
#  8   N_REN    2013 non-null   int64
#  9   P1       2013 non-null   int64
#  10  P2       2013 non-null   int64
#  11  P3_1     2013 non-null   int64
#  12  P3_2     2013 non-null   int64
#  13  P3_3     2013 non-null   int64
#  14  P3_4     2013 non-null   int64
#  15  P3_5     2013 non-null   int64
#  16  P3_6     2013 non-null   int64
#  17  P3_7     2013 non-null   int64
#  18  P3_8     2013 non-null   int64
#  19  P3_9     2013 non-null   int64
#  20  P3_10    2013 non-null   int64
#  21  P3_11    2013 non-null   int64
#  22  P4_1     2013 non-null   int64
#  23  P4_2     2013 non-null   int64
#  24  P4_3     2013 non-null   int64
#  25  P4_4     2013 non-null   int64
#  26  P4_5     2013 non-null   int64
#  27  P4_6     2013 non-null   int64
#  28  P4_7     2013 non-null   int64
#  29  P4_8     2013 non-null   int64
#  30  P4_9     2013 non-null   int64
#  31  P4_10    2013 non-null   int64
#  32  P5_1     2013 non-null   int64
#  33  P5_2     2013 non-null   int64
#  34  P5_3     2013 non-null   int64
#  35  P5_4     2013 non-null   int64
#  36  P5_5     2013 non-null   int64
#  37  P5_6     2013 non-null   int64
#  38  P5_7     2013 non-null   int64
#  39  P5_8     2013 non-null   int64
#  40  P5_9     2013 non-null   int64
#  41  P5_10    2013 non-null   int64
#  42  P5_11    2013 non-null   int64
#  43  P5_12    2013 non-null   int64
#  44  TIPO     2013 non-null   int64
#  45  FAC_MOD  2013 non-null   int64
# dtypes: int64(45), str(1)
# memory usage: 723.6 KB

# %%
df_cb_23.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2038 entries, 0 to 2037
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PER      2038 non-null   int64
#  1   N_ENT    2038 non-null   int64
#  2   FOL      2038 non-null   str
#  3   ENT      2038 non-null   int64
#  4   CON      2038 non-null   int64
#  5   V_SEL    2038 non-null   int64
#  6   N_HOG    2038 non-null   int64
#  7   H_MUD    2038 non-null   int64
#  8   N_REN    2038 non-null   int64
#  9   P1       2038 non-null   int64
#  10  P2       2038 non-null   int64
#  11  P3_1     2038 non-null   int64
#  12  P3_2     2038 non-null   int64
#  13  P3_3     2038 non-null   int64
#  14  P3_4     2038 non-null   int64
#  15  P3_5     2038 non-null   int64
#  16  P3_6     2038 non-null   int64
#  17  P3_7     2038 non-null   int64
#  18  P3_8     2038 non-null   int64
#  19  P3_9     2038 non-null   int64
#  20  P3_10    2038 non-null   int64
#  21  P3_11    2038 non-null   int64
#  22  P4_1     2038 non-null   int64
#  23  P4_2     2038 non-null   int64
#  24  P4_3     2038 non-null   int64
#  25  P4_4     2038 non-null   int64
#  26  P4_5     2038 non-null   int64
#  27  P4_6     2038 non-null   int64
#  28  P4_7     2038 non-null   int64
#  29  P4_8     2038 non-null   int64
#  30  P4_9     2038 non-null   int64
#  31  P4_10    2038 non-null   int64
#  32  P5_1     2038 non-null   int64
#  33  P5_2     2038 non-null   int64
#  34  P5_3     2038 non-null   int64
#  35  P5_4     2038 non-null   int64
#  36  P5_5     2038 non-null   int64
#  37  P5_6     2038 non-null   int64
#  38  P5_7     2038 non-null   int64
#  39  P5_8     2038 non-null   int64
#  40  P5_9     2038 non-null   int64
#  41  P5_10    2038 non-null   int64
#  42  P5_11    2038 non-null   int64
#  43  P5_12    2038 non-null   int64
#  44  TIPO     2038 non-null   int64
#  45  FAC_MOD  2038 non-null   int64
# dtypes: int64(45), str(1)
# memory usage: 732.5 KB

# %%
df_cb_24.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 46 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PER      1999 non-null   int64
#  1   N_ENT    1999 non-null   int64
#  2   FOL      1999 non-null   str
#  3   ENT      1999 non-null   int64
#  4   CON      1999 non-null   int64
#  5   V_SEL    1999 non-null   int64
#  6   N_HOG    1999 non-null   int64
#  7   H_MUD    1999 non-null   int64
#  8   N_REN    1999 non-null   int64
#  9   P1       1999 non-null   int64
#  10  P2       1999 non-null   int64
#  11  P3_1     1999 non-null   int64
#  12  P3_2     1999 non-null   int64
#  13  P3_3     1999 non-null   int64
#  14  P3_4     1999 non-null   int64
#  15  P3_5     1999 non-null   int64
#  16  P3_6     1999 non-null   int64
#  17  P3_7     1999 non-null   int64
#  18  P3_8     1999 non-null   int64
#  19  P3_9     1999 non-null   int64
#  20  P3_10    1999 non-null   int64
#  21  P3_11    1999 non-null   int64
#  22  P4_1     1999 non-null   int64
#  23  P4_2     1999 non-null   int64
#  24  P4_3     1999 non-null   int64
#  25  P4_4     1999 non-null   int64
#  26  P4_5     1999 non-null   int64
#  27  P4_6     1999 non-null   int64
#  28  P4_7     1999 non-null   int64
#  29  P4_8     1999 non-null   int64
#  30  P4_9     1999 non-null   int64
#  31  P4_10    1999 non-null   int64
#  32  P5_1     1999 non-null   int64
#  33  P5_2     1999 non-null   int64
#  34  P5_3     1999 non-null   int64
#  35  P5_4     1999 non-null   int64
#  36  P5_5     1999 non-null   int64
#  37  P5_6     1999 non-null   int64
#  38  P5_7     1999 non-null   int64
#  39  P5_8     1999 non-null   int64
#  40  P5_9     1999 non-null   int64
#  41  P5_10    1999 non-null   int64
#  42  P5_11    1999 non-null   int64
#  43  P5_12    1999 non-null   int64
#  44  TIPO     1999 non-null   int64
#  45  FAC_MOD  1999 non-null   int64
# dtypes: int64(45), str(1)
# memory usage: 718.5 KB

# %%
df_cs_21.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6651 entries, 0 to 6650
# Data columns (total 31 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   R_DEF_MOD  6651 non-null   int64
#  1   PER        6651 non-null   int64
#  2   N_ENT      6651 non-null   int64
#  3   FOL        6651 non-null   str
#  4   ENT        6651 non-null   int64
#  5   CON        6651 non-null   int64
#  6   V_SEL      6651 non-null   int64
#  7   N_HOG      6651 non-null   int64
#  8   H_MUD      6651 non-null   int64
#  9   N_REN      6651 non-null   int64
#  10  NOM        6651 non-null   str
#  11  C_RES      6651 non-null   int64
#  12  PAR        6382 non-null   float64
#  13  SEX        6382 non-null   float64
#  14  EDA        6382 non-null   float64
#  15  F_NAC      6369 non-null   str
#  16  ALF        6042 non-null   float64
#  17  I_NIV      6042 non-null   float64
#  18  I_ANIO     5893 non-null   float64
#  19  A_ESC      6042 non-null   float64
#  20  E_CON      5428 non-null   float64
#  21  C_ACT      5428 non-null   float64
#  22  OCU        2876 non-null   float64
#  23  A_ECO      2876 non-null   float64
#  24  POS        2876 non-null   float64
#  25  I_PER      2876 non-null   float64
#  26  ING        2837 non-null   float64
#  27  TIPO       6651 non-null   int64
#  28  ELEGIDO    1982 non-null   float64
#  29  FACTOR     6651 non-null   int64
#  30  FAC_MOD    6651 non-null   int64
# dtypes: float64(15), int64(13), str(3)
# memory usage: 1.6 MB

# %%
df_cs_22.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6771 entries, 0 to 6770
# Data columns (total 31 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   R_DEF_MOD  6771 non-null   int64
#  1   PER        6771 non-null   int64
#  2   N_ENT      6771 non-null   int64
#  3   FOL        6771 non-null   str
#  4   ENT        6771 non-null   int64
#  5   CON        6771 non-null   int64
#  6   V_SEL      6771 non-null   int64
#  7   N_HOG      6771 non-null   int64
#  8   H_MUD      6771 non-null   int64
#  9   N_REN      6771 non-null   int64
#  10  NOM        6771 non-null   str
#  11  C_RES      6771 non-null   int64
#  12  PAR        6771 non-null   str
#  13  SEX        6771 non-null   str
#  14  EDA        6771 non-null   str
#  15  F_NAC      6771 non-null   str
#  16  ALF        6771 non-null   str
#  17  I_NIV      6771 non-null   str
#  18  I_ANIO     6771 non-null   str
#  19  A_ESC      6771 non-null   str
#  20  E_CON      6771 non-null   str
#  21  C_ACT      6771 non-null   str
#  22  OCU        6771 non-null   str
#  23  A_ECO      6771 non-null   str
#  24  POS        6771 non-null   str
#  25  I_PER      6771 non-null   str
#  26  ING        6771 non-null   str
#  27  TIPO       6771 non-null   int64
#  28  ELEGIDO    6771 non-null   str
#  29  FACTOR     6771 non-null   int64
#  30  FAC_MOD    6771 non-null   int64
# dtypes: int64(13), str(18)
# memory usage: 1.6 MB

# %%
df_cs_23.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6841 entries, 0 to 6840
# Data columns (total 31 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   R_DEF_MOD  6841 non-null   int64
#  1   PER        6841 non-null   int64
#  2   N_ENT      6841 non-null   int64
#  3   FOL        6841 non-null   str
#  4   ENT        6841 non-null   int64
#  5   CON        6841 non-null   int64
#  6   V_SEL      6841 non-null   int64
#  7   N_HOG      6841 non-null   int64
#  8   H_MUD      6841 non-null   int64
#  9   N_REN      6841 non-null   int64
#  10  NOM        6841 non-null   str
#  11  C_RES      6841 non-null   int64
#  12  PAR        6841 non-null   str
#  13  SEX        6841 non-null   str
#  14  EDA        6841 non-null   str
#  15  F_NAC      6841 non-null   str
#  16  ALF        6841 non-null   str
#  17  I_NIV      6841 non-null   str
#  18  I_ANIO     6841 non-null   str
#  19  A_ESC      6841 non-null   str
#  20  E_CON      6841 non-null   str
#  21  C_ACT      6841 non-null   str
#  22  OCU        6841 non-null   str
#  23  A_ECO      6841 non-null   str
#  24  POS        6841 non-null   str
#  25  I_PER      6841 non-null   str
#  26  ING        6841 non-null   str
#  27  TIPO       6841 non-null   int64
#  28  ELEGIDO    6841 non-null   str
#  29  FACTOR     6841 non-null   int64
#  30  FAC_MOD    6841 non-null   int64
# dtypes: int64(13), str(18)
# memory usage: 1.6 MB

# %%
df_cs_24.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6692 entries, 0 to 6691
# Data columns (total 31 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   R_DEF_MOD  6692 non-null   int64
#  1   PER        6692 non-null   int64
#  2   N_ENT      6692 non-null   int64
#  3   FOL        6692 non-null   str
#  4   ENT        6692 non-null   int64
#  5   CON        6692 non-null   int64
#  6   V_SEL      6692 non-null   int64
#  7   N_HOG      6692 non-null   int64
#  8   H_MUD      6692 non-null   int64
#  9   N_REN      6692 non-null   int64
#  10  NOM        6692 non-null   str
#  11  C_RES      6692 non-null   int64
#  12  PAR        6692 non-null   int64
#  13  SEX        6692 non-null   int64
#  14  EDA        6692 non-null   int64
#  15  F_NAC      6692 non-null   str
#  16  ALF        6692 non-null   str
#  17  I_NIV      6692 non-null   str
#  18  I_ANIO     6692 non-null   str
#  19  A_ESC      6692 non-null   str
#  20  E_CON      6692 non-null   str
#  21  C_ACT      6692 non-null   str
#  22  OCU        6692 non-null   str
#  23  A_ECO      6692 non-null   str
#  24  POS        6692 non-null   str
#  25  I_PER      6692 non-null   str
#  26  ING        6692 non-null   str
#  27  TIPO       6692 non-null   int64
#  28  ELEGIDO    6692 non-null   str
#  29  FACTOR     6692 non-null   int64
#  30  FAC_MOD    6692 non-null   int64
# dtypes: int64(16), str(15)
# memory usage: 1.6 MB

# %%
df_viv_21.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2336 entries, 0 to 2335
# Data columns (total 37 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CD         2336 non-null   int64
#  1   PER        2336 non-null   int64
#  2   MPIO       2336 non-null   int64
#  3   N_ENT      2336 non-null   int64
#  4   AGEB       2336 non-null   str
#  5   UPM        2336 non-null   int64
#  6   AREA       2336 non-null   int64
#  7   FOL        2336 non-null   str
#  8   ENT        2336 non-null   int64
#  9   CON        2336 non-null   int64
#  10  N_PRO_VIV  2336 non-null   int64
#  11  V_SEL      2336 non-null   int64
#  12  N_HOG      2336 non-null   int64
#  13  H_MUD      2336 non-null   int64
#  14  R_PRE      2336 non-null   int64
#  15  FCH_PRE    2336 non-null   str
#  16  R_DEF      2336 non-null   int64
#  17  FCH_DEF    2336 non-null   str
#  18  E_OBS      2336 non-null   int64
#  19  RFC_ENT    2336 non-null   str
#  20  RFC_SUP    2336 non-null   str
#  21  P1         2000 non-null   float64
#  22  P2         1693 non-null   float64
#  23  P3         18 non-null     float64
#  24  P4         18 non-null     float64
#  25  R_INF      2000 non-null   float64
#  26  R_ELE      2000 non-null   float64
#  27  TEL        2336 non-null   str
#  28  R_HAB      2000 non-null   float64
#  29  R_NUE      2000 non-null   float64
#  30  R_AUS      2000 non-null   float64
#  31  DIASEM     2336 non-null   str
#  32  HORA       0 non-null      float64
#  33  R_PRE_MOD  2336 non-null   int64
#  34  R_DEF_MOD  2336 non-null   int64
#  35  TIPO       2336 non-null   int64
#  36  FACTOR     2336 non-null   int64
# dtypes: float64(10), int64(19), str(8)
# memory usage: 675.4 KB

# %%
df_viv_22.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2336 entries, 0 to 2335
# Data columns (total 37 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CD         2336 non-null   int64
#  1   PER        2336 non-null   int64
#  2   MPIO       2336 non-null   int64
#  3   N_ENT      2336 non-null   int64
#  4   AGEB       2336 non-null   str
#  5   UPM        2336 non-null   int64
#  6   AREA       2336 non-null   int64
#  7   FOL        2336 non-null   str
#  8   ENT        2336 non-null   int64
#  9   CON        2336 non-null   int64
#  10  N_PRO_VIV  2336 non-null   int64
#  11  V_SEL      2336 non-null   int64
#  12  N_HOG      2336 non-null   int64
#  13  H_MUD      2336 non-null   int64
#  14  R_PRE      2336 non-null   int64
#  15  FCH_PRE    2336 non-null   str
#  16  R_DEF      2336 non-null   int64
#  17  FCH_DEF    2336 non-null   str
#  18  E_OBS      2336 non-null   int64
#  19  RFC_ENT    2336 non-null   str
#  20  RFC_SUP    2336 non-null   str
#  21  P1         2336 non-null   str
#  22  P2         2336 non-null   str
#  23  P3         2336 non-null   str
#  24  P4         2336 non-null   str
#  25  R_INF      2336 non-null   str
#  26  R_ELE      2336 non-null   str
#  27  TEL        2336 non-null   str
#  28  R_HAB      2336 non-null   str
#  29  R_NUE      2336 non-null   str
#  30  R_AUS      2336 non-null   str
#  31  DIASEM     2336 non-null   str
#  32  HORA       2336 non-null   str
#  33  R_PRE_MOD  2336 non-null   int64
#  34  R_DEF_MOD  2336 non-null   int64
#  35  TIPO       2336 non-null   int64
#  36  FACTOR     2336 non-null   int64
# dtypes: int64(19), str(18)
# memory usage: 675.4 KB

# %%
df_viv_23.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2336 entries, 0 to 2335
# Data columns (total 37 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CD         2336 non-null   int64
#  1   PER        2336 non-null   int64
#  2   MPIO       2336 non-null   int64
#  3   N_ENT      2336 non-null   int64
#  4   AGEB       2336 non-null   str
#  5   UPM        2336 non-null   int64
#  6   AREA       2336 non-null   int64
#  7   FOL        2336 non-null   str
#  8   ENT        2336 non-null   int64
#  9   CON        2336 non-null   int64
#  10  N_PRO_VIV  2336 non-null   int64
#  11  V_SEL      2336 non-null   int64
#  12  N_HOG      2336 non-null   int64
#  13  H_MUD      2336 non-null   int64
#  14  R_PRE      2336 non-null   int64
#  15  FCH_PRE    2336 non-null   str
#  16  R_DEF      2336 non-null   int64
#  17  FCH_DEF    2336 non-null   str
#  18  E_OBS      2336 non-null   int64
#  19  RFC_ENT    2336 non-null   str
#  20  RFC_SUP    2336 non-null   str
#  21  P1         2336 non-null   str
#  22  P2         2336 non-null   str
#  23  P3         2336 non-null   str
#  24  P4         2336 non-null   str
#  25  R_INF      2336 non-null   str
#  26  R_ELE      2336 non-null   str
#  27  TEL        2336 non-null   str
#  28  R_HAB      2336 non-null   str
#  29  R_NUE      2336 non-null   str
#  30  R_AUS      2336 non-null   str
#  31  DIASEM     2336 non-null   str
#  32  HORA       2336 non-null   str
#  33  R_PRE_MOD  2336 non-null   int64
#  34  R_DEF_MOD  2336 non-null   int64
#  35  TIPO       2336 non-null   int64
#  36  FACTOR     2336 non-null   int64
# dtypes: int64(19), str(18)
# memory usage: 675.4 KB

# %%
df_viv_24.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2336 entries, 0 to 2335
# Data columns (total 39 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CD          2336 non-null   int64
#  1   PER         2336 non-null   int64
#  2   MPIO        2336 non-null   int64
#  3   N_ENT       2336 non-null   int64
#  4   AGEB        2336 non-null   str
#  5   UPM         2336 non-null   int64
#  6   AREA        2336 non-null   int64
#  7   FOL         2336 non-null   str
#  8   ENT         2336 non-null   int64
#  9   CON         2336 non-null   int64
#  10  N_PRO_VIV   2336 non-null   int64
#  11  V_SEL       2336 non-null   int64
#  12  N_HOG       2336 non-null   int64
#  13  H_MUD       2336 non-null   int64
#  14  R_PRE       2336 non-null   int64
#  15  FCH_PRE     2336 non-null   str
#  16  R_DEF       2336 non-null   int64
#  17  FCH_DEF     2336 non-null   str
#  18  E_OBS       2336 non-null   int64
#  19  CTA_ENT     2336 non-null   str
#  20  CTA_SUP     2336 non-null   str
#  21  P1          2336 non-null   str
#  22  P2          2336 non-null   str
#  23  P3          2336 non-null   str
#  24  P4          2336 non-null   str
#  25  R_INF       2336 non-null   str
#  26  R_ELE       2336 non-null   str
#  27  TEL         2336 non-null   str
#  28  R_HAB       2336 non-null   str
#  29  R_NUE       2336 non-null   str
#  30  R_AUS       2336 non-null   str
#  31  DIASEM      2336 non-null   str
#  32  HORA        2336 non-null   str
#  33  R_PRE_MOD   2336 non-null   int64
#  34  FCH_PRE_MO  2336 non-null   str
#  35  R_DEF_MOD   2336 non-null   int64
#  36  FCH_DEF_MO  2336 non-null   str
#  37  TIPO        2336 non-null   int64
#  38  FACTOR      2336 non-null   int64
# dtypes: int64(19), str(20)
# memory usage: 711.9 KB

# %% [markdown]
# ##### Se ha encontrado una discrepancia entre la cantidad de columnas en la tabla de viviendas del 2024 en comparación con las demás, teniendo 2 columnas sobrantes, pero eso se solucionara al limpiar las tablas despues del merge

# %%
# al ver que varias columnas tienen el mismo nombre y algunas no son primary key
#entonces procedemos a renombrarlas para en el caso que estn en otra tabla, se puedan identificar
#identificamos las columnas que son primary key y no se deben renombrar
llaves = ['PER', 'N_ENT', 'FOL', 'ENT', 'CON', 'V_SEL', 'N_HOG', 'H_MUD', 'N_REN']

#renombramos las columnas del dataframe que no son primary key, agregando un identificador
def identificar_columnas(df, ident):
    nuevas_columnas = {
        col: f"{ident}_{col}" if col not in llaves else col
        for col in df.columns
    }
    return df.rename(columns=nuevas_columnas)

#lo agregamos a cada una de las tablas que creamos
df_cb_21 = identificar_columnas(df_cb_21, 'cb')
df_cs_21 = identificar_columnas(df_cs_21, 'cs')
df_viv_21 = identificar_columnas(df_viv_21, 'viv')

df_cb_22 = identificar_columnas(df_cb_22, 'cb')
df_cs_22 = identificar_columnas(df_cs_22, 'cs')
df_viv_22 = identificar_columnas(df_viv_22, 'viv')

df_cb_23 = identificar_columnas(df_cb_23, 'cb')
df_cs_23 = identificar_columnas(df_cs_23, 'cs')
df_viv_23 = identificar_columnas(df_viv_23, 'viv')

df_cb_24 = identificar_columnas(df_cb_24, 'cb')
df_cs_24 = identificar_columnas(df_cs_24, 'cs')
df_viv_24 = identificar_columnas(df_viv_24, 'viv')

# %% [markdown]
# ### Unión de las tablas por año

# %%
#declaramos las columnas que funcionaran como primary key para el merge
key_persona = ['N_ENT', 'FOL', 'ENT', 'CON', 'V_SEL', 'N_HOG', 'H_MUD', 'N_REN']
key_vivienda = ['N_ENT', 'FOL', 'ENT', 'CON', 'V_SEL', 'N_HOG', 'H_MUD']

#realizamos el merge entre la tabla de BIARE y la tabla de sociodemografico para el año 2021
df_2021 = df_cb_21.merge(df_cs_21, on=key_persona, how='left')

#a nuestro dataframe de 2021 le agregamos la tabla de vivienda
df_2021 = df_2021.merge(df_viv_21, on=key_vivienda, how='left')

#por ultimo agregamos una nueva columna que nos indique el año de la encuesta
df_2021['ANIO'] = 2021

# %%
#realizamos el merge entre la tabla de BIARE y la tabla de sociodemografico para el año 2022
df_2022 = df_cb_22.merge(df_cs_22, on=key_persona, how='left')

#a nuestro dataframe de 2022 le agregamos la tabla de vivienda
df_2022 = df_2022.merge(df_viv_22, on=key_vivienda, how='left')

#por ultimo agregamos una nueva columna que nos indique el año de la encuesta
df_2022['ANIO'] = 2022

# %%
#realizamos el merge entre la tabla de BIARE y la tabla de sociodemografico para el año 2023
df_2023 = df_cb_23.merge(df_cs_23, on=key_persona, how='left')

#a nuestro dataframe de 2023 le agregamos la tabla de vivienda
df_2023 = df_2023.merge(df_viv_23, on=key_vivienda, how='left')

#por ultimo agregamos una nueva columna que nos indique el año de la encuesta
df_2023['ANIO'] = 2023

# %%
#realizamos el merge entre la tabla de BIARE y la tabla de sociodemografico para el año 2024
df_2024 = df_cb_24.merge(df_cs_24, on=key_persona, how='left')

#a nuestro dataframe de 2024 le agregamos la tabla de vivienda
df_2024 = df_2024.merge(df_viv_24, on=key_vivienda, how='left')

#por ultimo agregamos una nueva columna que nos indique el año de la encuesta
df_2024['ANIO'] = 2024

# %%
# verificamos que se haya realizado correctamente el merge de las tablas
print(df_2021.shape)
print(df_2022.shape)
print(df_2023.shape)
print(df_2024.shape)
# Out:
# (1969, 100)
# (2013, 100)
# (2038, 100)
# (1999, 102)

# %%
#juntamos todas las tablas en un solo dataframe
df_biare = pd.concat([df_2021, df_2022, df_2023, df_2024], ignore_index=True)

#verificamos que si se pasaron todas las columnas
df_biare.shape
# Out:
# (8019, 104)

# %% [markdown]
# ### Limpieza de los datos

# %%
#verificamos las columnas del nuevo dataset
nulos = df_biare.isna().sum().sort_values(ascending=False)
print(nulos[nulos > 0])
# Out:
# viv_FCH_DEF_MO    6020
# viv_FCH_PRE_MO    6020
# viv_CTA_SUP       6020
# viv_CTA_ENT       6020
# viv_RFC_ENT       1999
# viv_RFC_SUP       1999
# viv_HORA          1969
# viv_P3            1951
# viv_P4            1951
# cs_ING             776
# cs_A_ECO           768
# cs_POS             768
# cs_I_PER           768
# cs_OCU             768
# viv_P2             304
# cs_I_ANIO           48
# dtype: int64

# %%
#eliminamos todas las columnas que no nos serviran para nuestro analisis
eliminar_columnas = [
    'cb_TIPO', 'cb_FAC_MOD', 'cs_PAR', 'cs_C_RES', 'cs_F_NAC', 'cs_A_ESC',
    'cs_I_PER', 'cs_I_ANIO', 'cs_TIPO', 'cs_ELEGIDO', 'cs_FACTOR', 'cs_FAC_MOD',
    'cs_R_DEF_MOD', 'cs_NOM', 'viv_FCH_DEF_MO', 'viv_FCH_PRE_MO', 
    'viv_CTA_SUP', 'viv_CTA_ENT', 'viv_RFC_ENT', 'viv_RFC_SUP', 'viv_TIPO', 
    'viv_FACTOR', 'viv_HORA', 'viv_AGEB', 'viv_UPM', 'viv_AREA',
    'FOL', 'CON', 'viv_N_PRO_VIV', 'V_SEL', 'N_HOG', 'H_MUD',
    'viv_R_PRE', 'viv_R_DEF', 'viv_E_OBS', 'viv_R_INF', 'viv_R_ELE', 'viv_TEL',
    'viv_R_HAB', 'viv_R_NUE', 'viv_R_AUS', 'viv_DIASEM', 'viv_R_PRE_MOD',
    'viv_R_DEF_MOD', 'viv_CD', 'viv_MPIO', 'PER_x', 'PER_y', 'PER'
]

# %%
df_biare = df_biare.drop(columns=eliminar_columnas)
print(df_biare.shape)
print(df_biare.columns.tolist())
# Out:
# (8019, 55)
# ['N_ENT', 'ENT', 'N_REN', 'cb_P1', 'cb_P2', 'cb_P3_1', 'cb_P3_2', 'cb_P3_3', 'cb_P3_4', 'cb_P3_5', 'cb_P3_6', 'cb_P3_7', 'cb_P3_8', 'cb_P3_9', 'cb_P3_10', 'cb_P3_11', 'cb_P4_1', 'cb_P4_2', 'cb_P4_3', 'cb_P4_4', 'cb_P4_5', 'cb_P4_6', 'cb_P4_7', 'cb_P4_8', 'cb_P4_9', 'cb_P4_10', 'cb_P5_1', 'cb_P5_2', 'cb_P5_3', 'cb_P5_4', 'cb_P5_5', 'cb_P5_6', 'cb_P5_7', 'cb_P5_8', 'cb_P5_9', 'cb_P5_10', 'cb_P5_11', 'cb_P5_12', 'cs_SEX', 'cs_EDA', 'cs_ALF', 'cs_I_NIV', 'cs_E_CON', 'cs_C_ACT', 'cs_OCU', 'cs_A_ECO', 'cs_POS', 'cs_ING', 'viv_FCH_PRE', 'viv_FCH_DEF', 'viv_P1', 'viv_P2', 'viv_P3', 'viv_P4', 'ANIO']

# %%
#volvemos a verificar los nulos
nulos = df_biare.isna().sum().sort_values(ascending=False)
print(nulos[nulos > 0])
# Out:
# viv_P4      1951
# viv_P3      1951
# cs_ING       776
# cs_OCU       768
# cs_POS       768
# cs_A_ECO     768
# viv_P2       304
# dtype: int64

# %%
#como los datos númericos no podemos alterarlos, ya que para realizar el analisis estadistico
#si lo llenamos con 0 influira y si le ponemos la leyenda no aplica, no se podran realizar los analisis

#verificamos los tipos de datos de las columnas
df_biare.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8019 entries, 0 to 8018
# Data columns (total 55 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N_ENT        8019 non-null   int64
#  1   ENT          8019 non-null   int64
#  2   N_REN        8019 non-null   int64
#  3   cb_P1        8019 non-null   int64
#  4   cb_P2        8019 non-null   int64
#  5   cb_P3_1      8019 non-null   int64
#  6   cb_P3_2      8019 non-null   int64
#  7   cb_P3_3      8019 non-null   int64
#  8   cb_P3_4      8019 non-null   int64
#  9   cb_P3_5      8019 non-null   int64
#  10  cb_P3_6      8019 non-null   int64
#  11  cb_P3_7      8019 non-null   int64
#  12  cb_P3_8      8019 non-null   int64
#  13  cb_P3_9      8019 non-null   int64
#  14  cb_P3_10     8019 non-null   int64
#  15  cb_P3_11     8019 non-null   int64
#  16  cb_P4_1      8019 non-null   int64
#  17  cb_P4_2      8019 non-null   int64
#  18  cb_P4_3      8019 non-null   int64
#  19  cb_P4_4      8019 non-null   int64
#  20  cb_P4_5      8019 non-null   int64
#  21  cb_P4_6      8019 non-null   int64
#  22  cb_P4_7      8019 non-null   int64
#  23  cb_P4_8      8019 non-null   int64
#  24  cb_P4_9      8019 non-null   int64
#  25  cb_P4_10     8019 non-null   int64
#  26  cb_P5_1      8019 non-null   int64
#  27  cb_P5_2      8019 non-null   int64
#  28  cb_P5_3      8019 non-null   int64
#  29  cb_P5_4      8019 non-null   int64
#  30  cb_P5_5      8019 non-null   int64
#  31  cb_P5_6      8019 non-null   int64
#  32  cb_P5_7      8019 non-null   int64
#  33  cb_P5_8      8019 non-null   int64
#  34  cb_P5_9      8019 non-null   int64
#  35  cb_P5_10     8019 non-null   int64
#  36  cb_P5_11     8019 non-null   int64
#  37  cb_P5_12     8019 non-null   int64
#  38  cs_SEX       8019 non-null   object
#  39  cs_EDA       8019 non-null   object
#  40  cs_ALF       8019 non-null   object
#  41  cs_I_NIV     8019 non-null   object
#  42  cs_E_CON     8019 non-null   object
#  43  cs_C_ACT     8019 non-null   object
#  44  cs_OCU       7251 non-null   object
#  45  cs_A_ECO     7251 non-null   object
#  46  cs_POS       7251 non-null   object
#  47  cs_ING       7243 non-null   object
#  48  viv_FCH_PRE  8019 non-null   str
#  49  viv_FCH_DEF  8019 non-null   str
#  50  viv_P1       8019 non-null   object
#  51  viv_P2       7715 non-null   object
#  52  viv_P3       6068 non-null   object
#  53  viv_P4       6068 non-null   object
#  54  ANIO         8019 non-null   int64
# dtypes: int64(39), object(14), str(2)
# memory usage: 3.4+ MB

# %%
#verificamos los datos de la columna cs_SEX, ya que aparece como object
df_biare['cs_SEX'].unique()

#como el sexo aparece como 1 y 2, procedemos a cambiarlo por Hombre y Mujer, respectivamente
df_biare['cs_SEX'] = pd.to_numeric(df_biare['cs_SEX'], errors='coerce')
df_biare['cs_SEX'] = df_biare['cs_SEX'].map({1: 'Hombre', 2: 'Mujer'})

#verificamos que se hagan los cambios correctamente
df_biare['cs_SEX'].unique()
# Out:
# <StringArray>
# ['Mujer', 'Hombre']
# Length: 2, dtype: str

# %%
#verificamos los datos de la columna cs_EDA, ya que aparece como object
df_biare['cs_EDA'].unique()

#vemos que algunas edades aparecen como str y otras como int, por lo que procedemos a convertirlas primero a numero y luego a int
df_biare['cs_EDA'] = pd.to_numeric(df_biare['cs_EDA'], errors='coerce')
df_biare['cs_EDA'] = df_biare['cs_EDA'].astype('Int64')

#verificamos que ningun valor sea menor a 15 ni tampoco mayor a 120
df_biare['cs_EDA'].min()
df_biare['cs_EDA'].max()

#verificamos que se hagan los cambios correctamente
df_biare['cs_EDA'].unique()
# Out:
# <IntegerArray>
# [51, 28, 56, 54, 19, 22, 21, 24, 59, 46, 26, 39, 41, 34, 35, 18, 74, 38, 42,
#  33, 57, 27, 64, 60, 29, 62, 25, 52, 47, 73, 76, 20, 53, 43, 84, 50, 36, 67,
#  40, 58, 31, 23, 55, 32, 44, 70, 37, 49, 80, 30, 48, 69, 68, 81, 45, 61, 63,
#  66, 86, 82, 65, 77, 72, 71, 78, 95, 90, 97, 89, 75, 79, 88, 91, 87, 83, 85,
#  93, 96, 94, 92]
# Length: 80, dtype: Int64

# %%
#verificamos los datos de la columna cs_ALF, ya que aparece como object
df_biare['cs_ALF'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_ALF'] = pd.to_numeric(df_biare['cs_ALF'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_ALF'] = df_biare['cs_ALF'].map({1: 'Sabe leer y escribir', 2: 'No sabe leer y escribir', 9: 'No especificado'})

#verificamos que se hayan realizado los cambios
df_biare['cs_ALF'].unique()
# Out:
# <StringArray>
# ['Sabe leer y escribir', 'No sabe leer y escribir', 'No especificado']
# Length: 3, dtype: str

# %%
#verificamos los datos de la columna cs_I_NIV, ya que aparece como object
df_biare['cs_I_NIV'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_I_NIV'] = pd.to_numeric(df_biare['cs_I_NIV'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_I_NIV'] = df_biare['cs_I_NIV'].map({0: 'Ninguno', 1: 'Preescolar', 2: 'Primaria',
    3: 'Secundaria', 4: 'Preparatoria o bachillerato', 5: 'Normal', 6: 'Carrera técnica',
    7: 'Profesional', 8: 'Maestría', 9: 'Doctorado', 99: 'No sabe'
})

#verificamos que se hayan realizado los cambios
df_biare['cs_I_NIV'].unique()
# Out:
# <StringArray>
# [                   'Maestría',                 'Profesional',
#  'Preparatoria o bachillerato',                  'Secundaria',
#                     'Primaria',                   'Doctorado',
#              'Carrera técnica',                     'Ninguno',
#                       'Normal',                     'No sabe',
#                   'Preescolar']
# Length: 11, dtype: str

# %%
#verificamos los datos de la columna cs_E_CON, ya que aparece como object
df_biare['cs_E_CON'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_E_CON'] = pd.to_numeric(df_biare['cs_E_CON'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_E_CON'] = df_biare['cs_E_CON'].map({1: 'Unión libre', 2: 'Separado(a)',
    3: 'Divorciado(a)', 4: 'Viudo(a)', 5: 'Casado(a)', 6: 'Soltero(a)',
    9: 'No especificado'
})

#verificamos que se hayan realizado los cambios
df_biare['cs_E_CON'].unique()
# Out:
# <StringArray>
# [     'Soltero(a)',       'Casado(a)',     'Unión libre',   'Divorciado(a)',
#         'Viudo(a)',     'Separado(a)', 'No especificado']
# Length: 7, dtype: str

# %%
#verificamos los datos de la columna cs_C_ACT, ya que aparece como object
df_biare['cs_C_ACT'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_C_ACT'] = pd.to_numeric(df_biare['cs_C_ACT'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_C_ACT'] = df_biare['cs_C_ACT'].map({
    1: 'Trabajó por lo menos una hora para obtener ingresos',
    2: 'Trabajó sin pago ayudando a un familiar',
    3: 'No trabajó, pero sí tiene trabajo',
    4: 'Buscó trabajo',
    5: 'Espera respuesta a una solicitud de trabajo',
    6: 'Estudiante',
    7: 'Se dedica a los quehaceres del hogar',
    8: 'Jubilado(a) o pensionado(a)',
    9: 'Incapacitado(a) permanentemente para trabajar',
    10: 'Otra situación',
    99: 'No especificado'
})

#verificamos que se hayan realizado los cambios
df_biare['cs_C_ACT'].unique()
# Out:
# <StringArray>
# [        'Espera respuesta a una solicitud de trabajo',
#  'Trabajó por lo menos una hora para obtener ingresos',
#                 'Se dedica a los quehaceres del hogar',
#                                        'Buscó trabajo',
#                                           'Estudiante',
#                          'Jubilado(a) o pensionado(a)',
#                    'No trabajó, pero sí tiene trabajo',
#                                       'Otra situación',
#              'Trabajó sin pago ayudando a un familiar',
#        'Incapacitado(a) permanentemente para trabajar',
#                                      'No especificado']
# Length: 11, dtype: str

# %%
#verificamos los datos de la columna cs_OCU, ya que aparece como object
df_biare['cs_OCU'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_OCU'] = pd.to_numeric(df_biare['cs_OCU'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_OCU'] = df_biare['cs_OCU'].map({
    1: 'Profesionistas y técnicos',
    2: 'Funcionarios de los sectores público y privado',
    3: 'Personal administrativo',
    4: 'Comerciantes, vendedores y similares',
    5: 'Trabajadores en servicios personales y conductores de vehículos',
    6: 'Trabajadores en labores agropecuarias',
    7: 'Trabajadores industriales',
    9: 'No especificado'
})

#llenamos los nulos como 'no trabaja'
df_biare['cs_OCU'] = df_biare['cs_OCU'].fillna('No trabaja')

#verificamos que se hayan realizado los cambios
df_biare['cs_OCU'].unique()
# Out:
# <StringArray>
# [                                                     'No trabaja',
#                                        'Profesionistas y técnicos',
#                             'Comerciantes, vendedores y similares',
#  'Trabajadores en servicios personales y conductores de vehículos',
#                                        'Trabajadores industriales',
#                                          'Personal administrativo',
#                            'Trabajadores en labores agropecuarias',
#                   'Funcionarios de los sectores público y privado',
#                                                  'No especificado']
# Length: 9, dtype: str

# %%
#verificamos los datos de la columna cs_A_ECO, ya que aparece como object
df_biare['cs_A_ECO'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_A_ECO'] = pd.to_numeric(df_biare['cs_A_ECO'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_A_ECO'] = df_biare['cs_A_ECO'].map({1: 'Agropecuaria', 2: 'Industria',
    3: 'Construcción', 4: 'Comercio', 5: 'Servicios', 6: 'Comunicaciones y transportes',
    7: 'Administración pública y defensa', 9: 'No especificado'
})

#llenamos los nulos como 'no trabaja'
df_biare['cs_A_ECO'] = df_biare['cs_A_ECO'].fillna('No trabaja')

#verificamos que se hayan realizado los cambios
df_biare['cs_A_ECO'].unique()
# Out:
# <StringArray>
# [                      'No trabaja',                        'Industria',
#                          'Comercio',                        'Servicios',
#                      'Construcción',     'Comunicaciones y transportes',
#  'Administración pública y defensa',                     'Agropecuaria',
#                   'No especificado']
# Length: 9, dtype: str

# %%
#verificamos los datos de la columna cs_POS, ya que aparece como object
df_biare['cs_POS'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_POS'] = pd.to_numeric(df_biare['cs_POS'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['cs_POS'] = df_biare['cs_POS'].map({
    1: 'Patrón(a)',
    2: 'Trabajador(a) por su cuenta',
    3: 'Trabajador(a) a sueldo fijo, salario o jornal',
    4: 'Trabajador(a) a destajo',
    5: 'Trabajador(a) a comisión o porcentaje',
    6: 'Trabajador(a) sin pago',
    9: 'No sabe'
})

#llenamos los nulos como 'no trabaja'
df_biare['cs_POS'] = df_biare['cs_POS'].fillna('No trabaja')

#verificamos que se hayan realizado los cambios
df_biare['cs_POS'].unique()
# Out:
# <StringArray>
# [                                   'No trabaja',
#  'Trabajador(a) a sueldo fijo, salario o jornal',
#                    'Trabajador(a) por su cuenta',
#                         'Trabajador(a) sin pago',
#                        'Trabajador(a) a destajo',
#                                      'Patrón(a)',
#          'Trabajador(a) a comisión o porcentaje',
#                                        'No sabe']
# Length: 8, dtype: str

# %%
#verificamos los datos de la columna cs_ING, ya que aparece como object
df_biare['cs_ING'].unique()

#como vemos que hay nulos en distintos formatos, primero los estandarizamos
df_biare['cs_ING'] = df_biare['cs_ING'].replace(999999, np.nan)
df_biare['cs_ING'] = df_biare['cs_ING'].replace(' ', np.nan)

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['cs_ING'] = pd.to_numeric(df_biare['cs_ING'], errors='coerce')

#convertimos el conjunto a un tipo de dato float
df_biare['cs_ING'] = df_biare['cs_ING'].astype('float64')
#verificamos que se hayan realizado los cambios
df_biare['cs_ING'].unique()
# Out:
# array([        nan, 9.00000e+03, 1.00000e+03, 6.50000e+03, 8.00000e+02,
#        1.20000e+03, 9.00000e+02, 3.40000e+03, 3.20000e+03, 1.10000e+03,
#        1.50000e+03, 1.40000e+03, 1.60000e+03, 2.20000e+04, 5.00000e+03,
#        2.00000e+03, 5.50000e+03, 2.20000e+03, 2.50000e+03, 1.80000e+03,
#        6.00000e+03, 3.00000e+03, 1.30000e+03, 1.90000e+03, 4.50000e+03,
#        1.50000e+04, 4.00000e+03, 4.00000e+02, 8.60000e+03, 7.00000e+03,
#        3.00000e+04, 1.98000e+03, 3.00000e+02, 1.30000e+04, 7.00000e+02,
#        1.40000e+04, 3.30000e+03, 2.30000e+03, 8.90000e+03, 5.00000e+02,
#        1.10000e+04, 2.00000e+04, 2.10000e+03, 6.00000e+02, 8.00000e+03,
#        1.00000e+04, 3.50000e+03, 1.20000e+04, 1.70000e+04, 2.50000e+04,
#        5.00000e+04, 1.00000e+02, 3.88000e+03, 3.90000e+03, 9.50000e+02,
#        1.70000e+03, 9.99900e+03, 7.50000e+03, 2.70000e+03, 5.20000e+03,
#        8.50000e+02, 2.40000e+03, 1.05000e+03, 1.75000e+03, 2.70000e+04,
#        1.15000e+03, 6.20000e+03, 2.00000e+02, 5.32000e+03, 1.25000e+03,
#        9.20000e+03, 3.60000e+03, 4.00000e+04, 3.70000e+03, 1.90000e+04,
#        2.75000e+03, 4.20000e+03, 1.65000e+03, 9.40000e+03, 2.80000e+03,
#        3.50000e+02, 2.50000e+02, 2.60000e+03, 3.10000e+03, 4.10000e+03,
#        7.20000e+03, 5.60000e+03, 9.99999e+05, 4.30000e+03, 3.80000e+03,
#        4.80000e+03, 4.60000e+03, 1.50000e+02, 7.00000e+04, 1.25000e+04,
#        1.60000e+04, 8.50000e+03, 2.90000e+03, 1.35000e+03, 4.90000e+03,
#        5.30000e+03, 5.00000e+01, 2.40000e+04, 9.50000e+03, 7.30000e+03,
#        4.55000e+03, 1.05000e+04, 3.50000e+04, 4.70000e+03, 1.53600e+03,
#        6.50000e+02, 1.65000e+04, 7.80000e+03, 4.50000e+02, 2.40000e+02,
#        7.50000e+02, 5.80000e+03, 6.00000e+04, 5.40000e+03, 2.10000e+04,
#        3.95000e+03, 1.80000e+04, 6.55000e+03, 1.47000e+03, 2.22000e+04,
#        4.40000e+03, 2.25000e+04, 8.00000e+04, 4.60000e+04, 7.75000e+03,
#        1.01000e+04, 3.25000e+03, 1.99500e+03, 9.90000e+01, 9.99000e+02,
#        8.40000e+03, 7.45000e+03, 4.50000e+04, 8.70000e+03, 1.50000e+05,
#        4.98000e+03, 2.30000e+04, 3.75000e+02, 8.00000e+01, 1.35000e+04,
#        7.40000e+03, 1.28800e+03, 5.50000e+04, 1.15000e+04, 4.08000e+02,
#        5.90000e+03, 3.25800e+03])

# %%
#verificamos los datos de la columna viv_P1, ya que aparece como object
df_biare['viv_P1'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico y luego a int
df_biare['viv_P1'] = pd.to_numeric(df_biare['viv_P1'], errors='coerce')
df_biare['viv_P1'] = df_biare['viv_P1'].astype('Int64')

#verificamos que se hayan realizado los cambios
df_biare['viv_P1'].unique()
# Out:
# <IntegerArray>
# [2, 3, 4, 5, 1, 6, 11, 7, 9, 8, 10, 14, 12, 16, 15, 13]
# Length: 16, dtype: Int64

# %%
#verificamos los datos de la columna viv_P2, ya que aparece como object
df_biare['viv_P2'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['viv_P2'] = pd.to_numeric(df_biare['viv_P2'], errors='coerce')

#especificamos el significado de cada uno de los numeros
df_biare['viv_P2'] = df_biare['viv_P2'].map({1: 'Sí', 2: 'No'})

#llenamos los nulos como 'No aplica'
df_biare['viv_P2'] = df_biare['viv_P2'].fillna('No aplica')

#verificamos que se hayan realizado los cambios
df_biare['viv_P2'].unique()
# Out:
# <StringArray>
# ['Sí', 'No aplica', 'No']
# Length: 3, dtype: str

# %%
#verificamos los datos de la columna viv_P3, ya que aparece como object
df_biare['viv_P3'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['viv_P3'] = pd.to_numeric(df_biare['viv_P3'], errors='coerce')

#llenamos los nulos como 1
df_biare['viv_P3'] = df_biare['viv_P3'].fillna(1)

#cambiamos el tipo de dato a int
df_biare['viv_P3'] = df_biare['viv_P3'].astype('Int64')

#verificamos que se hayan realizado los cambios
df_biare['viv_P3'].unique()
# Out:
# <IntegerArray>
# [1, 2, 3, 4, 5]
# Length: 5, dtype: Int64

# %%
#verificamos los datos de la columna viv_P4, ya que aparece como object
df_biare['viv_P4'].unique()

#como vemos que algunos valores aparecen como str y otros como int, los corvertimos a numerico
df_biare['viv_P4'] = pd.to_numeric(df_biare['viv_P4'], errors='coerce')

#llenamos los nulos de p4 con el valor de su p1
df_biare['viv_P4'] = df_biare['viv_P4'].fillna(df_biare['viv_P1'])

#cambiamos el tipo de dato a int
df_biare['viv_P4'] = df_biare['viv_P4'].astype('Int64')

#verificamos que se hayan realizado los cambios
df_biare['viv_P4'].unique()
# Out:
# <IntegerArray>
# [2, 3, 4, 5, 1, 6, 11, 7, 9, 8, 10, 16, 14, 13]
# Length: 14, dtype: Int64

# %%
df_biare.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8019 entries, 0 to 8018
# Data columns (total 55 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N_ENT        8019 non-null   int64
#  1   ENT          8019 non-null   int64
#  2   N_REN        8019 non-null   int64
#  3   cb_P1        8019 non-null   int64
#  4   cb_P2        8019 non-null   int64
#  5   cb_P3_1      8019 non-null   int64
#  6   cb_P3_2      8019 non-null   int64
#  7   cb_P3_3      8019 non-null   int64
#  8   cb_P3_4      8019 non-null   int64
#  9   cb_P3_5      8019 non-null   int64
#  10  cb_P3_6      8019 non-null   int64
#  11  cb_P3_7      8019 non-null   int64
#  12  cb_P3_8      8019 non-null   int64
#  13  cb_P3_9      8019 non-null   int64
#  14  cb_P3_10     8019 non-null   int64
#  15  cb_P3_11     8019 non-null   int64
#  16  cb_P4_1      8019 non-null   int64
#  17  cb_P4_2      8019 non-null   int64
#  18  cb_P4_3      8019 non-null   int64
#  19  cb_P4_4      8019 non-null   int64
#  20  cb_P4_5      8019 non-null   int64
#  21  cb_P4_6      8019 non-null   int64
#  22  cb_P4_7      8019 non-null   int64
#  23  cb_P4_8      8019 non-null   int64
#  24  cb_P4_9      8019 non-null   int64
#  25  cb_P4_10     8019 non-null   int64
#  26  cb_P5_1      8019 non-null   int64
#  27  cb_P5_2      8019 non-null   int64
#  28  cb_P5_3      8019 non-null   int64
#  29  cb_P5_4      8019 non-null   int64
#  30  cb_P5_5      8019 non-null   int64
#  31  cb_P5_6      8019 non-null   int64
#  32  cb_P5_7      8019 non-null   int64
#  33  cb_P5_8      8019 non-null   int64
#  34  cb_P5_9      8019 non-null   int64
#  35  cb_P5_10     8019 non-null   int64
#  36  cb_P5_11     8019 non-null   int64
#  37  cb_P5_12     8019 non-null   int64
#  38  cs_SEX       8019 non-null   str
#  39  cs_EDA       8019 non-null   Int64
#  40  cs_ALF       8019 non-null   str
#  41  cs_I_NIV     8019 non-null   str
#  42  cs_E_CON     8019 non-null   str
#  43  cs_C_ACT     8019 non-null   str
#  44  cs_OCU       8019 non-null   str
#  45  cs_A_ECO     8019 non-null   str
#  46  cs_POS       8019 non-null   str
#  47  cs_ING       4676 non-null   float64
#  48  viv_FCH_PRE  8019 non-null   str
#  49  viv_FCH_DEF  8019 non-null   str
#  50  viv_P1       8019 non-null   Int64
#  51  viv_P2       8019 non-null   str
#  52  viv_P3       8019 non-null   Int64
#  53  viv_P4       8019 non-null   Int64
#  54  ANIO         8019 non-null   int64
# dtypes: Int64(4), float64(1), int64(39), str(11)
# memory usage: 3.4 MB

# %%
#convertimos N_ENT y N_REN a str ya que son identificadores
df_biare['N_ENT'] = df_biare['N_ENT'].astype(str)
df_biare['N_REN'] = df_biare['N_REN'].astype(str)

#como vemos que algunos valores de ENT aparecen como str y otros como int, los corvertimos a numerico
df_biare['ENT'] = pd.to_numeric(df_biare['ENT'], errors='coerce')

#definimos los valores de cada numero
ent_dict = {
    1: 'Aguascalientes', 2: 'Baja California', 3: 'Baja California Sur',
    4: 'Campeche', 5: 'Coahuila', 6: 'Colima', 7: 'Chiapas', 8: 'Chihuahua',
    9: 'Ciudad de México', 10: 'Durango', 11: 'Guanajuato', 12: 'Guerrero',
    13: 'Hidalgo', 14: 'Jalisco', 15: 'México', 16: 'Michoacán', 17: 'Morelos',
    18: 'Nayarit', 19: 'Nuevo León', 20: 'Oaxaca', 21: 'Puebla', 22: 'Querétaro',
    23: 'Quintana Roo', 24: 'San Luis Potosí', 25: 'Sinaloa', 26: 'Sonora',
    27: 'Tabasco', 28: 'Tamaulipas', 29: 'Tlaxcala', 30: 'Veracruz',
    31: 'Yucatán',32: 'Zacatecas'
}

#convertimos los numeros en estados
df_biare['ENT'] = df_biare['ENT'].map(ent_dict)

df_biare['ENT'].unique()
# Out:
# <StringArray>
# [     'Aguascalientes',     'Baja California', 'Baja California Sur',
#             'Campeche',            'Coahuila',              'Colima',
#              'Chiapas',           'Chihuahua',    'Ciudad de México',
#              'Durango',          'Guanajuato',            'Guerrero',
#              'Hidalgo',             'Jalisco',              'México',
#            'Michoacán',             'Morelos',             'Nayarit',
#           'Nuevo León',              'Oaxaca',              'Puebla',
#            'Querétaro',        'Quintana Roo',     'San Luis Potosí',
#              'Sinaloa',              'Sonora',             'Tabasco',
#           'Tamaulipas',            'Tlaxcala',            'Veracruz',
#              'Yucatán',           'Zacatecas']
# Length: 32, dtype: str

# %%
#convertimos las columnas de fechas en tipo de dato datetime
df_biare['viv_FCH_PRE'] = pd.to_datetime(df_biare['viv_FCH_PRE'], format='%d/%m/%Y', errors='coerce')
df_biare['viv_FCH_DEF'] = pd.to_datetime(df_biare['viv_FCH_DEF'], format='%d/%m/%Y', errors='coerce')

df_biare[['viv_FCH_PRE', 'viv_FCH_DEF']].info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8019 entries, 0 to 8018
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   viv_FCH_PRE  8019 non-null   datetime64[us]
#  1   viv_FCH_DEF  8019 non-null   datetime64[us]
# dtypes: datetime64[us](2)
# memory usage: 125.4 KB

# %%
#guardamos en csv nuestro dataset limpio
df_biare.to_csv('../Limpieza de datos/biare_limpio_2021_2024.csv', index=False, encoding='utf-8-sig')
